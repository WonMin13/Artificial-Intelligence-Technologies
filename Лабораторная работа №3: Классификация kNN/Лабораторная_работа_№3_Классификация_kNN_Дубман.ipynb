# %% [markdown]
# <a href="https://colab.research.google.com/github/WonMin13/Artificial-Intelligence-Technologies/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%20%E2%84%963%3A%20%D0%9A%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D1%8F%20kNN/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%963_%D0%9A%D0%BB%D0%B0%D1%81%D1%81%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D1%8F_kNN_%D0%94%D1%83%D0%B1%D0%BC%D0%B0%D0%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание

# %% [markdown]
# ## Задание 1. Считать в pandas.DataFrame любой источник данных:

# %% [markdown]
# * Блок с отступами
# * CSV,
# * JSON,
# * Excel-файл,
# * HTML-таблицу и т.п.

# %% [markdown]
# ## Задание 2. Бинарная классификация

# %% [markdown]
# * Привести описание датасета.
#
# * Осуществить предобработку данных (избавиться от null, убрать некоторые признаки и т.п.) - "подчистить данные".
#
# * Закодировать категориальные признаки при необходимости.
#
# * Выбрать какое-нибудь значение гиперпараметра *k* алгоритма *kNN*.
#
# * Разбить выборку на обучающую и тестовую.
#
#       Разбиение использовать одно и то же для всех последующих манипуляций.
#
# * Осуществить бинарную классификацию.
#
# * Посчитать метрики: *accuracy, precision, recall, f-measure* , а также составить classification_report.
#
# * Нормализовать данные (StandardScaler или MinMaxScaler).
#
# * Осуществить бинарную классификацию.
# * Посчитать метрики: *accuracy, precision, recall, f-measure* , а также составить classification_report.
#
# * Сравнить метрики на данных без нормализации и с применением нормализации.
#
#       Далее используем нормализованные данные.
#
# * Построить сorrelation heatmap и/или воспользоваться методом corr(). Выбрать наиболее важные признаки эвристически или на основании каких-нибудь вычислений (см. примечание).
#
# * Осуществить бинарную классификацию с отфильтрованными признаками.
#
# * Посчитать метрики: *accuracy, precision, recall, f-measure* , а также составить classification_report.
#
# * Сравнить результаты "до" и "после" фильтрации, сделать выводы.
#
#       Естественно, искомые результаты - улучшение метрик.
#
# * Перебрать значения гиперпараметра *k* в каком-нибудь диапазоне с использованием кросс-валидации на данных с отфильтрованными признаками. Построить график train/test accuracy в зависимости от значения *k*.
#
#       данных - исходных данных до разбиения с применением нормализации

# %% [markdown]
# ## Задание 3. Многоклассовая классификация

# %% [markdown]
# * Многоклассовая классификация:
#
# * Привести описание датасета.
#
# * Осуществить предобработку данных - "подчистить данные".
#
# * Закодировать категориальные признаки при необходимости.
#
# * Нормализовать данные.
#
# * Выбрать какое-нибудь значение гиперпараметра *k*
#  алгоритма *kNN*
#
# * Разбить выборку на обучающую и тестовую.
#
# * Разбиение использовать одно и то же для данных без фильтрации признаков и с применением фильтрации.
#
# * Осуществить многоклассовую классификацию.
#
# * Посчитать метрики: *accuracy, precision, recall, f-measure* , а также составить classification_report.
#
# * Построить сorrelation heatmap и/или воспользоваться методом corr(). Выбрать наиболее важные признаки эвристически или на основании каких-нибудь вычислений (см. примечание).
#
# * Осуществить многоклассовую классификацию с отфильтрованными признаками.
# *  Посчитать метрики: *accuracy, precision, recall, f-measure* , а также составить classification_report.
# * Сравнить результаты "до" и "после" фильтрации, сделать выводы.
#
# * Перебрать значения гиперпараметра *k* в каком-нибудь диапазоне с использованием кросс-валидации на данных с отфильтрованными признаками. Построить график train/test accuracy в зависимости от значения.
#
#       данных - исходных данных до разбиения
#
# * Для лучшего классификатора привести метрики, classification_report, построить confusion matrix (это вроде матрицы *TN/TP/FN/FP*, только расширенной для многоклассовой классификации, чтобы понять, в какие стороны чаще ошибается классификатор).

# %% [markdown]
# # Выполнение заданий лабораторной работы

# %% [markdown]
# ## Задание 1. Загрузка библиотек и датасета.

# %% [markdown]
# ### Загрузка библиотек

# %% [markdown]
# Подключим необходимые для работы библиотеки. Так же подключим Google Drive, который облегчит загрузку датасета в программу, и уберет необходимость в подгрузке через средства коллаба, требующие достаточное количество времени.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Загрузка данных.

# %%
df_columns = pd.read_csv('/content/drive/MyDrive/datasets/columns.csv')
df_responses = pd.read_csv('/content/drive/MyDrive/datasets/responses.csv')

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Посмотрим на полученные данные.

# %%
df_responses
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0       5.0                       3.0    2.0   1.0      2.0              2.0
# 1       4.0                       4.0    2.0   1.0      1.0              1.0
# 2       5.0                       5.0    2.0   2.0      3.0              4.0
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 4       5.0                       3.0    4.0   3.0      2.0              4.0
# ...     ...                       ...    ...   ...      ...              ...
# 1005    5.0                       2.0    5.0   2.0      2.0              5.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
# 1007    4.0                       3.0    1.0   1.0      2.0              2.0
# 1008    5.0                       3.0    3.0   3.0      1.0              3.0
# 1009    5.0                       5.0    4.0   3.0      2.0              3.0
#
#       Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0         1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1         2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2         5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3         1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4         3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
# ...       ...  ...   ...                ...  ...   ...     ...     ...
# 1005      4.0  4.0   4.0                3.0  ...  20.0   164.0    57.0
# 1006      1.0  4.0   1.0                1.0  ...  27.0   183.0    80.0
# 1007      2.0  3.0   4.0                1.0  ...  18.0   173.0    75.0
# 1008      1.0  3.0   4.0                1.0  ...  25.0   173.0    58.0
# 1009      3.0  4.0   1.0                1.0  ...  21.0   185.0    72.0
#
#       Number of siblings  Gender  Left - right handed  \
# 0                    1.0  female         right handed
# 1                    2.0  female         right handed
# 2                    2.0  female         right handed
# 3                    1.0  female         right handed
# 4                    1.0  female         right handed
# ...                  ...     ...                  ...
# 1005                 1.0  female         right handed
# 1006                 5.0    male          left handed
# 1007                 0.0  female         right handed
# 1008                 1.0  female         right handed
# 1009                 1.0    male         right handed
#
#                     Education  Only child  Village - town  \
# 0     college/bachelor degree          no         village
# 1     college/bachelor degree          no            city
# 2            secondary school          no            city
# 3     college/bachelor degree         yes            city
# 4            secondary school          no         village
# ...                       ...         ...             ...
# 1005         secondary school          no            city
# 1006           masters degree          no         village
# 1007         secondary school         yes            city
# 1008  college/bachelor degree          no            city
# 1009         secondary school          no         village
#
#       House - block of flats
# 0             block of flats
# 1             block of flats
# 2             block of flats
# 3             house/bungalow
# 4             house/bungalow
# ...                      ...
# 1005          house/bungalow
# 1006          house/bungalow
# 1007          block of flats
# 1008          block of flats
# 1009          house/bungalow
#
# [1010 rows x 150 columns]

# %% [markdown]
# Датасет состоит из 150 столбцов (из них 139 - целочисленных и 11 - категориальных)
#
# Одна строка - ответ на опрос одного изх студентов факультета статистики FSEV UK (граждане Словакии от 15 до 30 лет).
#
# Данные содержат пропуски
#
# Все столбцы можно разделить на следующие группы:
#
# * Музыкальные предпочтения (19 столбцов)
# * Предпотения в фильмах (12 пунктов)
# * Хобби и интересы (32 шт.)
# * Фобии (10 шт.)
# * Здоровые привычки (3 предмета)
# * Черты характера, взгляды на жизнь и мнения (57 пунктов)
# * Привычки (7 пунктов)
# * Демографические особенности (10 элементов)

# %% [markdown]
# **Узнаем название столбца в таблице df_responses по названию 'Drinking' из описания датасета**

# %%
df_columns[df_columns['original']=='Drinking']
# Out:
#     original    short
# 74  Drinking  Alcohol

# %%
data = df_responses[['Age', 'Height',	'Weight', 'Music', 'Movies', 'Smoking', 'Alcohol', 'Healthy eating', 'Number of siblings', 'Village - town', 'House - block of flats', 'Only child', 'Education']]
data = data.dropna()
data
# Out:
#        Age  Height  Weight  Music  Movies         Smoking         Alcohol  \
# 0     20.0   163.0    48.0    5.0     5.0    never smoked     drink a lot
# 1     19.0   163.0    58.0    4.0     5.0    never smoked     drink a lot
# 2     20.0   176.0    67.0    5.0     5.0   tried smoking     drink a lot
# 3     22.0   172.0    59.0    5.0     5.0   former smoker     drink a lot
# 4     20.0   170.0    59.0    5.0     5.0   tried smoking  social drinker
# ...    ...     ...     ...    ...     ...             ...             ...
# 1005  20.0   164.0    57.0    5.0     5.0  current smoker     drink a lot
# 1006  27.0   183.0    80.0    4.0     5.0    never smoked  social drinker
# 1007  18.0   173.0    75.0    4.0     4.0   tried smoking  social drinker
# 1008  25.0   173.0    58.0    5.0     5.0   tried smoking  social drinker
# 1009  21.0   185.0    72.0    5.0     5.0   tried smoking  social drinker
#
#       Healthy eating  Number of siblings Village - town  \
# 0                4.0                 1.0        village
# 1                3.0                 2.0           city
# 2                3.0                 2.0           city
# 3                3.0                 1.0           city
# 4                4.0                 1.0        village
# ...              ...                 ...            ...
# 1005             3.0                 1.0           city
# 1006             3.0                 5.0        village
# 1007             2.0                 0.0           city
# 1008             3.0                 1.0           city
# 1009             3.0                 1.0        village
#
#      House - block of flats Only child                Education
# 0            block of flats         no  college/bachelor degree
# 1            block of flats         no  college/bachelor degree
# 2            block of flats         no         secondary school
# 3            house/bungalow        yes  college/bachelor degree
# 4            house/bungalow         no         secondary school
# ...                     ...        ...                      ...
# 1005         house/bungalow         no         secondary school
# 1006         house/bungalow         no           masters degree
# 1007         block of flats        yes         secondary school
# 1008         block of flats         no  college/bachelor degree
# 1009         house/bungalow         no         secondary school
#
# [949 rows x 13 columns]

# %% [markdown]
# ### Кодируем категориальные признаки с помощью Label-Encoding

# %% [markdown]
# **Кодируем столбец Smoking**

# %%
from sklearn import preprocessing

le_smoking = preprocessing.LabelEncoder()
le_smoking.fit(data['Smoking'])
le_smoking.classes_
# Out:
# array(['current smoker', 'former smoker', 'never smoked', 'tried smoking'],
#       dtype=object)

# %% [markdown]
# **Хардкодим признаки т.к. они неверно посортированы в le_smoking.classes_**

# %%
data['Smoking'] = data['Smoking'].apply(lambda x: ['never smoked', 'tried smoking', 'former smoker', 'current smoker'].index(x))
data.head(1)
# Out:
#     Age  Height  Weight  Music  Movies  Smoking      Alcohol  Healthy eating  \
# 0  20.0   163.0    48.0    5.0     5.0        0  drink a lot             4.0
#
#    Number of siblings Village - town House - block of flats Only child  \
# 0                 1.0        village         block of flats         no
#
#                  Education
# 0  college/bachelor degree

# %% [markdown]
# **Кодируем столбец Alcohol**

# %%
le_alcohol = preprocessing.LabelEncoder()
le_alcohol.fit(data['Alcohol'])
le_alcohol.classes_
# Out:
# array(['drink a lot', 'never', 'social drinker'], dtype=object)

# %% [markdown]
# **Хардкодим признаки т.к. они неверно посортированы в le_smoking.classes_**

# %%
data['Alcohol'] = data['Alcohol'].apply(lambda x: ['never', 'social drinker', 'drink a lot'].index(x))
data.head(1)
# Out:
#     Age  Height  Weight  Music  Movies  Smoking  Alcohol  Healthy eating  \
# 0  20.0   163.0    48.0    5.0     5.0        0        2             4.0
#
#    Number of siblings Village - town House - block of flats Only child  \
# 0                 1.0        village         block of flats         no
#
#                  Education
# 0  college/bachelor degree

# %% [markdown]
# **Кодируем столбец Village - town**

# %%
le_village = preprocessing.LabelEncoder()
le_village.fit(data['Village - town'])
le_village.classes_
# Out:
# array(['city', 'village'], dtype=object)

# %%
data['Village - town'] = le_village.transform(data['Village - town'])
data.head(1)
# Out:
#     Age  Height  Weight  Music  Movies  Smoking  Alcohol  Healthy eating  \
# 0  20.0   163.0    48.0    5.0     5.0        0        2             4.0
#
#    Number of siblings  Village - town House - block of flats Only child  \
# 0                 1.0               1         block of flats         no
#
#                  Education
# 0  college/bachelor degree

# %% [markdown]
# **Кодируем столбец House - block of flats**

# %%
le_house = preprocessing.LabelEncoder()
le_house.fit(data['House - block of flats'])
le_house.classes_
# Out:
# array(['block of flats', 'house/bungalow'], dtype=object)

# %%
data['House - block of flats'] = le_house.transform(data['House - block of flats'])
data.head(1)
# Out:
#     Age  Height  Weight  Music  Movies  Smoking  Alcohol  Healthy eating  \
# 0  20.0   163.0    48.0    5.0     5.0        0        2             4.0
#
#    Number of siblings  Village - town  House - block of flats Only child  \
# 0                 1.0               1                       0         no
#
#                  Education
# 0  college/bachelor degree

# %% [markdown]
# **Кодируем столбец Only child**

# %%
le_only_child = preprocessing.LabelEncoder()
le_only_child.fit(data['Only child'])
le_only_child.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data['Only child'] = le_only_child.transform(data['Only child'])
data.head(1)
# Out:
#     Age  Height  Weight  Music  Movies  Smoking  Alcohol  Healthy eating  \
# 0  20.0   163.0    48.0    5.0     5.0        0        2             4.0
#
#    Number of siblings  Village - town  House - block of flats  Only child  \
# 0                 1.0               1                       0           0
#
#                  Education
# 0  college/bachelor degree

# %% [markdown]
# **Анализуем целевой класс Education**

# %%
fig, ax = plt.subplots(figsize=(15,5))
#sns.countplot(data['Education'], palette='vlag')
#sns.countplot(data['Education'], palette='vlag', hue=data['Education'], legend=False)
sns.countplot(data=data, x='Education', hue='Education', palette='vlag', legend=False)

ax.set(title='Количество людей в каждом классе')
plt.show()

# %% [markdown]
# **Отфильтровываем слишком мелкие классы**

# %%
data = data[data['Education']!='doctorate degree']
data = data[data['Education']!='currently a primary school pupil']
data.head(3)
# Out:
#     Age  Height  Weight  Music  Movies  Smoking  Alcohol  Healthy eating  \
# 0  20.0   163.0    48.0    5.0     5.0        0        2             4.0
# 1  19.0   163.0    58.0    4.0     5.0        0        2             3.0
# 2  20.0   176.0    67.0    5.0     5.0        1        2             3.0
#
#    Number of siblings  Village - town  House - block of flats  Only child  \
# 0                 1.0               1                       0           0
# 1                 2.0               0                       0           0
# 2                 2.0               0                       0           0
#
#                  Education
# 0  college/bachelor degree
# 1  college/bachelor degree
# 2         secondary school

# %%
fig, ax = plt.subplots(figsize=(15,5))
#sns.countplot(data['Education'], palette='vlag')
#sns.countplot(data['Education'], palette='vlag', hue=data['Education'], legend=False)
sns.countplot(data=data, x='Education', hue='Education', palette='vlag', legend=False)
ax.set(title='Количество людей в каждом классе')
plt.show()

# %% [markdown]
# **Кодируем целевой столбец Education**

# %%
le_education = preprocessing.LabelEncoder()
le_education.fit(data['Education'])
le_education.classes_
# Out:
# array(['college/bachelor degree', 'masters degree', 'primary school',
#        'secondary school'], dtype=object)

# %%
data['Education'] = data['Education'].apply(lambda x: ['primary school', 'secondary school', 'college/bachelor degree', 'masters degree'].index(x))
data.head(1)
# Out:
#     Age  Height  Weight  Music  Movies  Smoking  Alcohol  Healthy eating  \
# 0  20.0   163.0    48.0    5.0     5.0        0        2             4.0
#
#    Number of siblings  Village - town  House - block of flats  Only child  \
# 0                 1.0               1                       0           0
#
#    Education
# 0          2

# %% [markdown]
# ### Изучим корреляцию между признаками

# %%
sns.set(rc={"figure.figsize":(15, 8)})


corr = data.corr(method='spearman')
sns.heatmap(corr,
            square=True,
            linewidths=.5,
            cbar_kws={"shrink": .5},
            annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Видно существенную корреляцию между возрастом и уровнем образования.

# %% [markdown]
# ## Задание 2. Бинарная классификация

# %% [markdown]
# ### Без нормализации

# %% [markdown]
# **Узнаем название столбца в таблице df_responses по названию 'I wish I could change the past because of the things I have done.' из описания датасета.**

# %%
df_columns[df_columns['original']=='I wish I could change the past because of the things I have done.']
# Out:
#                                               original              short
# 102  I wish I could change the past because of the ...  Changing the past

# %% [markdown]
# **Получим названия столбцов в df_responses, которые соответвуют разделу "PERSONALITY TRAITS, VIEWS ON LIFE & OPINIONS"**

# %%
list_columns_personality_trails = df_columns.iloc[76:76+57]['short'].tolist()
list_columns_personality_trails.remove("Changing the past")
list_columns_personality_trails.remove("Punctuality")
list_columns_personality_trails.remove("Lying")
list_columns_personality_trails.remove("Internet usage")
list_columns_personality_trails.append("Village - town")

# %%
data_binary = df_responses[list_columns_personality_trails]
data_binary = data_binary.dropna()
data_binary.head(1)
# Out:
#    Daily events  Prioritising workload  Writing notes  Workaholism  \
# 0           2.0                    2.0            5.0          4.0
#
#    Thinking ahead  Final judgement  Reliability  Keeping promises  \
# 0             2.0              5.0          4.0               4.0
#
#    Loss of interest  Friends versus money  ...  Happiness in life  \
# 0               1.0                   3.0  ...                4.0
#
#    Energy levels  Small - big dogs  Personality  Finding lost valuables  \
# 0            5.0               1.0          4.0                     3.0
#
#    Getting up  Interests or hobbies  Parents' advice  Questionnaires or polls  \
# 0         2.0                   3.0              4.0                      3.0
#
#    Village - town
# 0         village
#
# [1 rows x 54 columns]

# %% [markdown]
# **Кодируем целевой бинарный столбец Village - town**

# %%
le_village_binary = preprocessing.LabelEncoder()
le_village_binary.fit(data_binary['Village - town'])
le_village_binary.classes_
# Out:
# array(['city', 'village'], dtype=object)

# %%
data_binary['Village - town'] = le_village_binary.transform(data_binary['Village - town'])
data_binary.head(1)
# Out:
#    Daily events  Prioritising workload  Writing notes  Workaholism  \
# 0           2.0                    2.0            5.0          4.0
#
#    Thinking ahead  Final judgement  Reliability  Keeping promises  \
# 0             2.0              5.0          4.0               4.0
#
#    Loss of interest  Friends versus money  ...  Happiness in life  \
# 0               1.0                   3.0  ...                4.0
#
#    Energy levels  Small - big dogs  Personality  Finding lost valuables  \
# 0            5.0               1.0          4.0                     3.0
#
#    Getting up  Interests or hobbies  Parents' advice  Questionnaires or polls  \
# 0         2.0                   3.0              4.0                      3.0
#
#    Village - town
# 0               1
#
# [1 rows x 54 columns]

# %%
sns.set(rc={"figure.figsize":(60, 32)})


corr_binary = data_binary.corr(method='spearman')
sns.heatmap(corr_binary,
            square=True,
            linewidths=.5,
            cbar_kws={"shrink": .5},
            annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **Вернем обратно адекватный размер поля sns**

# %%
sns.set(rc={"figure.figsize":(15, 8)})

# %% [markdown]
# Тут много интересных и очевидных корреляций можно найти.
# Из не столь очевидных корреляций: Согласие с утверждением "Я ипохондрик." скоррелировано с согласием на утверждением "Я могу очень легко разозлиться." с коэфф корреляции Спирмана = 0.14

# %% [markdown]
# *Сколь существенной корреляции в данных с целевым полем Village - town нет*

# %% [markdown]
# **Разделяем target и features**

# %%
import sklearn
import sklearn.neighbors
from sklearn.metrics import r2_score, confusion_matrix, classification_report, confusion_matrix
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
y_binary = data_binary['Village - town']
X_binary = data_binary.drop(['Village - town'], axis=1)

# %%
X_train_binary, X_test_binary, y_train_binary, y_test_binary = sklearn.model_selection.train_test_split(
    X_binary, y_binary, test_size=0.25, random_state=1)

# %%
training_accuracy_binary = []
test_accuracy_binary = []

neighbors_settings_binary = range(3, 55, 3)
for n_neighbors in neighbors_settings_binary:
    clf = sklearn.neighbors.KNeighborsClassifier( n_neighbors = n_neighbors )
    clf.fit( X_train_binary, y_train_binary )
    training_accuracy_binary.append( clf.score(X_train_binary, y_train_binary) )
    test_accuracy_binary.append( clf.score(X_test_binary, y_test_binary) )

plt.plot( neighbors_settings_binary, training_accuracy_binary, label="train accuracy" )
plt.plot( neighbors_settings_binary, test_accuracy_binary, label="test accuracy" )
plt.ylabel("accuracy")
plt.xlabel("k")
g = plt.legend()

# %% [markdown]
# ### С нормализацией

# %%
scaler = MinMaxScaler()
X_train_binary_n = scaler.fit_transform(X_train_binary)
X_test_binary_n = scaler.transform(X_test_binary)

# %%
y = data['Education']
X = data.drop(['Education'], axis=1)

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(
    X, y, test_size=0.25, random_state=0)

# %%
X_train.head(2)
# Out:
#       Age  Height  Weight  Music  Movies  Smoking  Alcohol  Healthy eating  \
# 827  20.0   168.0    55.0    5.0     4.0        1        2             4.0
# 836  19.0   187.0    88.0    5.0     5.0        1        1             3.0
#
#      Number of siblings  Village - town  House - block of flats  Only child
# 827                 1.0               0                       0           0
# 836                 0.0               0                       0           1

# %%
training_accuracy_binary_n = []
test_accuracy_binary_n = []
neighbors_settings = range(3, 55, 3)
neighbors_settings_n = range(3, 55, 3)
neighbors_settings_binary_n = range(3, 55, 3)
for n_neighbors in neighbors_settings_binary_n:
    clf = sklearn.neighbors.KNeighborsClassifier( n_neighbors = n_neighbors )
    clf.fit( X_train_binary_n, y_train_binary )
    training_accuracy_binary_n.append( clf.score(X_train_binary_n, y_train_binary) )
    test_accuracy_binary_n.append( clf.score(X_test_binary_n, y_test_binary) )

plt.plot( neighbors_settings_binary_n, training_accuracy_binary_n, label="train accuracy" )
plt.plot( neighbors_settings_binary_n, test_accuracy_binary_n, label="test accuracy" )
plt.ylabel("accuracy")
plt.xlabel("k")
g = plt.legend()

# %%
plt.plot( neighbors_settings, training_accuracy_binary, label="train accuracy" )
plt.plot( neighbors_settings, test_accuracy_binary, label="test accuracy" )
plt.plot( neighbors_settings_n, training_accuracy_binary_n, label="train_n accuracy" )
plt.plot( neighbors_settings_n, test_accuracy_binary_n, label="test_n accuracy" )
plt.ylabel("accuracy")
plt.xlabel("k")
g = plt.legend()
print("Маскимальное значение accuracy без нормализации %.4f" % max(test_accuracy_binary))
print("Маскимальное значение accuracy после нормализации %.4f" % max(test_accuracy_binary_n))
# Out:
# Маскимальное значение accuracy без нормализации 0.6820
# Маскимальное значение accuracy после нормализации 0.6820

# %% [markdown]
# В данном случае, что с нормализацией, что без нормализации были абсолютно идентичные значения accuracy при выбранных k алгоритма KNN.

# %% [markdown]
# **Выберем лучшиее значение гиперпараметра k=18 и выведем `classification_report` и `confusion_matrix`**

# %%
knn = sklearn.neighbors.KNeighborsClassifier(n_neighbors=18)
knn.fit(X_train_binary_n, y_train_binary)
predictions_binary = knn.predict(X_test_binary_n)

# %%
print("kNN")
print(classification_report(y_test_binary, predictions_binary))
# Out:
# kNN
#               precision    recall  f1-score   support
#
#            0       0.68      0.99      0.81       148
#            1       0.50      0.01      0.03        69
#
#     accuracy                           0.68       217
#    macro avg       0.59      0.50      0.42       217
# weighted avg       0.63      0.68      0.56       217

# %%
conf_matrix = confusion_matrix(y_test_binary, predictions_binary)
sns.heatmap(conf_matrix, annot=True, fmt="d")
# Out:
# <Axes: >

# %% [markdown]
# ## Задание 3. Многоклассовая классификация

# %% [markdown]
# ### Без нормализации

# %%
import sklearn
import sklearn.neighbors
from sklearn.metrics import r2_score, confusion_matrix, classification_report, confusion_matrix
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# **Разделяем targets и features**

# %%
y = data['Education']
X = data.drop(['Education'], axis=1)

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(
    X, y, test_size=0.25, random_state=0)

# %%
training_accuracy = []
test_accuracy = []

neighbors_settings = range(3, 55, 3)
for n_neighbors in neighbors_settings:
    clf = sklearn.neighbors.KNeighborsClassifier( n_neighbors = n_neighbors )
    clf.fit( X_train, y_train )
    training_accuracy.append( clf.score(X_train, y_train) )
    test_accuracy.append( clf.score(X_test, y_test) )

plt.plot( neighbors_settings, training_accuracy, label="train accuracy" )
plt.plot( neighbors_settings, test_accuracy, label="test accuracy" )
plt.ylabel("accuracy")
plt.xlabel("k")
g = plt.legend()

# %% [markdown]
# ### С нормализацией

# %%
scaler = MinMaxScaler()
X_train_n = scaler.fit_transform(X_train)
X_test_n = scaler.transform(X_test)

# %%
X_train.head(2)
# Out:
#       Age  Height  Weight  Music  Movies  Smoking  Alcohol  Healthy eating  \
# 827  20.0   168.0    55.0    5.0     4.0        1        2             4.0
# 836  19.0   187.0    88.0    5.0     5.0        1        1             3.0
#
#      Number of siblings  Village - town  House - block of flats  Only child
# 827                 1.0               0                       0           0
# 836                 0.0               0                       0           1

# %%
training_accuracy_n = []
test_accuracy_n = []

neighbors_settings_n = range(3, 55, 3)
for n_neighbors in neighbors_settings_n:
    clf = sklearn.neighbors.KNeighborsClassifier( n_neighbors = n_neighbors )
    clf.fit( X_train_n, y_train )
    training_accuracy_n.append( clf.score(X_train_n, y_train) )
    test_accuracy_n.append( clf.score(X_test_n, y_test) )

plt.plot( neighbors_settings_n, training_accuracy_n, label="train accuracy" )
plt.plot( neighbors_settings_n, test_accuracy_n, label="test accuracy" )
plt.ylabel("accuracy")
plt.xlabel("k")
g = plt.legend()

# %%
plt.plot( neighbors_settings, training_accuracy, label="train accuracy" )
plt.plot( neighbors_settings, test_accuracy, label="train accuracy" )
plt.plot( neighbors_settings_n, training_accuracy_n, label="train_n accuracy" )
plt.plot( neighbors_settings_n, test_accuracy_n, label="test_n accuracy" )
plt.ylabel("accuracy")
plt.xlabel("k")
g = plt.legend()
print("Маскимальное значение accuracy без нормализации %.4f" % max(test_accuracy))
print("Маскимальное значение accuracy после нормализации %.4f" % max(test_accuracy_n))
# Out:
# Маскимальное значение accuracy без нормализации 0.6197
# Маскимальное значение accuracy после нормализации 0.6282

# %% [markdown]
# Accuracy в среднем для нормализованных данных немного лучше, чем для ненормализованных.
#
# Возможно, это из-за того, что в исходных данных нет выбросов - это опросник в котором пользователи выбирали конечное число вариантов ответов.

# %% [markdown]
# **Выберем лучшиее значение гиперпараметра и выведем `classification_report` и `confusion_matrix`**

# %%
knn = sklearn.neighbors.KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train_n, y_train)
predictions = knn.predict(X_test_n)

# %%
print("kNN")
print(classification_report(y_test, predictions))
# Out:
# kNN
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        17
#            1       0.64      0.95      0.76       143
#            2       0.40      0.08      0.13        53
#            3       0.88      0.33      0.48        21
#
#     accuracy                           0.63       234
#    macro avg       0.48      0.34      0.34       234
# weighted avg       0.56      0.63      0.54       234

# %%
conf_matrix = confusion_matrix(y_test, predictions)
sns.heatmap(conf_matrix, annot=True, fmt="d")
# Out:
# <Axes: >
